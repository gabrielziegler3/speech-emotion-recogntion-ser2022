# %% [markdown]
# # Baseline1 - Model Training (Prosodic Features) - PT-BR-SER (Coraa V6)
#
# This is a baseline model trained with prosodic features. We use a simple MLP implementation of scikit-learn.
#
# We recommend that participants explore different classification models, feature selection, data balancing, data augmentation and other techniques such as classifier ensemble.

# %% [markdown]
# # Prosodic Features
#
# Related methods.
#
# > Luengo, I., Navas, E., Hernáez, I., & Sánchez, J. (2005). Automatic emotion recognition using prosodic parameters. In Ninth European conference on speech communication and technology.
#
# > Rao, K. S., Koolagudi, S. G., & Vempada, R. R. (2013). Emotion recognition from speech using global and local prosodic features. International journal of speech technology, 16(2), 143-160.

# %%
import pandas as pd


df_prosodic = pd.read_csv('prosodic_features.csv').sort_values(by='sound_filepath')
df_prosodic
# Out:
#                                      sound_filepath  local_jitter  \
# 176           train/bfamcv01_segment163_neutral.wav      0.028242
# 318  train/bfamcv01_segment168_non-neutral-male.wav      0.023441
# 243  train/bfamcv01_segment170_non-neutral-male.wav      0.025107
# 29            train/bfamcv01_segment173_neutral.wav      0.024952
# 108           train/bfamcv01_segment177_neutral.wav      0.033259
# ..                                              ...           ...
# 378            train/bpubmn14_segment87_neutral.wav      0.041100
# 166            train/bpubmn14_segment89_neutral.wav      0.024239
# 446            train/bpubmn14_segment92_neutral.wav      0.036892
# 405            train/bpubmn14_segment95_neutral.wav      0.030630
# 79             train/bpubmn14_segment98_neutral.wav      0.026912
#
#      local_shimmer  min_intensity  relative_min_intensity_time  max_intensity  \
# 176       0.142011      39.708540                     0.265683      77.218046
# 318       0.151924      40.001809                     0.510550      80.188905
# 243       0.155780      54.215080                     0.021131      82.647111
# 29        0.137728      41.921520                     0.916337      80.672787
# 108       0.166011      40.513441                     0.025059      79.816216
# ..             ...            ...                          ...            ...
# 378       0.141838      42.126983                     0.462094      74.910851
# 166       0.089185      32.775147                     0.191657      83.519998
# 446       0.147278      46.896159                     0.396711      75.489070
# 405       0.131234      35.496753                     0.008154      79.249207
# 79        0.153911      35.340392                     0.406610      81.176883
#
#      relative_max_intensity_time  mean_intensity  stddev_intensity  \
# 176                     0.939734       54.882812         11.290841
# 318                     0.915009       65.918816         10.749796
# 243                     0.222413       73.301110          5.615585
# 29                      0.713576       65.547409          9.102396
# 108                     0.661608       61.535998         10.995404
# ..                           ...             ...               ...
# 378                     0.526314       61.839477          8.295658
# 166                     0.127268       62.643103         13.508191
# 446                     0.258380       62.336150          9.449077
# 405                     0.606163       63.141842         10.564453
# 79                      0.654597       62.582742         11.378426
#
#      q1_intensity  ...    f2_median    f3_median    f4_median  \
# 176     42.222614  ...  1668.704638  2780.747781  3864.331639
# 318     59.660497  ...  1495.071504  2665.935573  3759.576021
# 243     69.633575  ...  1518.161653  2617.090499  3685.031540
# 29      60.707451  ...  1855.881674  2745.636280  3758.225874
# 108     53.425930  ...  1428.677716  2676.218905  3688.047035
# ..            ...  ...          ...          ...          ...
# 378     55.210783  ...  1678.011206  2708.243626  4119.592452
# 166     52.108283  ...  1401.257606  2570.854063  4121.385381
# 446     51.194764  ...  1599.102467  2719.948762  4049.753725
# 405     57.478244  ...  1469.688653  2648.861557  4008.300379
# 79      52.714129  ...  1500.540909  2573.021953  4037.532624
#
#      formant_dispersion  average_formant          mff  fitch_vtl      delta_f  \
# 176         1111.428274      2210.957718  1755.829831  15.955502  1106.910026
# 318         1065.739244      2120.735347  1703.789338  16.454911  1064.149591
# 243         1056.800377      2083.728525  1656.793388  16.907869  1046.423539
# 29          1062.169591      2232.865232  1819.027804  15.420238  1099.407730
# 108         1042.658269      2088.253971  1676.386283  16.738004  1048.655456
# ..                  ...              ...          ...        ...          ...
# 378         1205.076034      2252.552908  1752.953134  16.003611  1140.875316
# 166         1225.602858      2134.518464  1602.862834  17.573502  1103.626610
# 446         1195.993764      2207.644347  1688.781287  16.643356  1123.978565
# 405         1188.653000      2142.297992  1620.879044  17.359837  1098.900423
# 79          1188.137398      2146.053979  1647.952804  17.040359  1097.680507
#
#      vtl_delta_f             label
# 176    15.809776           neutral
# 318    16.445056  non-neutral-male
# 243    16.723630  non-neutral-male
# 29     15.917661           neutral
# 108    16.688036           neutral
# ..           ...               ...
# 378    15.339100           neutral
# 166    15.856812           neutral
# 446    15.569692           neutral
# 405    15.925010           neutral
# 79     15.942708           neutral
#
# [625 rows x 58 columns]

# %% [markdown]
# # Selecting Prosodic Features

# %%
features = ['local_jitter', 'local_shimmer', 'min_intensity',
       'relative_min_intensity_time', 'max_intensity',
       'relative_max_intensity_time', 'mean_intensity', 'stddev_intensity',
       'q1_intensity', 'median_intensity', 'q3_intensity', 'voiced_fraction',
       'min_pitch', 'relative_min_pitch_time', 'max_pitch',
       'relative_max_pitch_time', 'mean_pitch', 'stddev_pitch', 'q1_pitch',
       'q3_pitch', 'mean_absolute_pitch_slope',
       'pitch_slope_without_octave_jumps', 'min_hnr', 'relative_min_hnr_time',
       'max_hnr', 'relative_max_hnr_time', 'mean_hnr', 'stddev_hnr', 'min_gne',
       'max_gne', 'mean_gne', 'stddev_gne', 'sum_gne', 'band_energy',
       'band_density', 'band_energy_difference', 'band_density_difference',
       'center_of_gravity_spectrum', 'stddev_spectrum', 'skewness_spectrum',
       'kurtosis_spectrum', 'central_moment_spectrum', 'f1_mean', 'f2_mean',
       'f3_mean', 'f4_mean', 'f1_median', 'f2_median', 'f3_median',
       'f4_median', 'formant_dispersion', 'average_formant', 'mff',
       'fitch_vtl', 'delta_f', 'vtl_delta_f']

X = df_prosodic[features]
y = df_prosodic.label.to_list()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[ 0.15466298,  0.03759922,  0.00903401, ..., -0.08195452,
#          0.09025836, -0.13605919],
#        [-0.37707385,  0.28815011,  0.03791452, ...,  0.41144312,
#         -0.75567687,  0.74055292],
#        [-0.19249342,  0.38560712,  1.43760817, ...,  0.85894865,
#         -1.10635364,  1.12495186],
#        ...,
#        [ 1.11269049,  0.17071896,  0.71685586, ...,  0.59761982,
#          0.42792746, -0.46734766],
#        [ 0.41917904, -0.23481335, -0.40573416, ...,  1.30547642,
#         -0.06819665,  0.02294944],
#        [ 0.00737131,  0.33837638, -0.42113221, ...,  0.98984362,
#         -0.09233041,  0.04737115]])

# %% [markdown]
# # Model Selection

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.dummy import DummyClassifier

import numpy as np


classifiers = [MLPClassifier(activation='logistic',random_state=1,max_iter=3000),
               MLPClassifier(activation='tanh',random_state=1,max_iter=3000),
               MLPClassifier(activation='relu',random_state=1,max_iter=3000),
               DummyClassifier(strategy="most_frequent",random_state=1),
               DummyClassifier(strategy="stratified",random_state=1),
               DummyClassifier(strategy="uniform",random_state=1)]

# %%
for classifier in classifiers:
    print('Running ',classifier)
    kf=StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
    scores=cross_val_score(classifier, X, y, cv=kf, scoring='f1_macro')
    print(scores,'f1_macro=',np.mean(scores))
    print('-------')
# Out:
# Running  MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=3000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=1, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)
# [0.5715551  0.553338   0.57689003 0.43440978 0.54970933] f1_macro= 0.537180449941826
# -------
# Running  MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=3000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=1, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)
# [0.63754703 0.49586823 0.51693412 0.37865194 0.51543302] f1_macro= 0.5088868696709696
# -------
# Running  MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=3000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=1, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)
# [0.4983298  0.47240555 0.52793651 0.44845831 0.48979831] f1_macro= 0.4873856953989737
# -------
# Running  DummyClassifier(constant=None, random_state=1, strategy='most_frequent')
# [0.29464286 0.29297459 0.29297459 0.29297459 0.29297459] f1_macro= 0.293308242579543
# -------
# Running  DummyClassifier(constant=None, random_state=1, strategy='stratified')
# [0.25215889 0.3655754  0.25545635 0.31498016 0.29563492] f1_macro= 0.2967611440085533
# -------
# Running  DummyClassifier(constant=None, random_state=1, strategy='uniform')
# [0.33344038 0.29380901 0.22442136 0.28958045 0.31497303] f1_macro= 0.29124484573188997
# -------

# %% [markdown]
# # Model Training

# %%
clf = MLPClassifier(activation='logistic',random_state=1,max_iter=3000)
clf.fit(X,y)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=3000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=1, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
import pickle

with open('model.prosodic.pkl', 'wb') as fid_model:
    pickle.dump(clf,fid_model)

with open('scaler.prosodic.pkl', 'wb') as fid_scaler:
    pickle.dump(sc,fid_scaler)
